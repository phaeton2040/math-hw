# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
### Формала для круга в полярных координатах
### r = const

# %%
dots = 360
R = np.full(dots, 40)
alpha = np.linspace(0, 2 * np.pi, dots)
plt.polar(alpha, R)
plt.show()
